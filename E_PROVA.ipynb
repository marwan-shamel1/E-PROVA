# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# الربط ب درايف
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/IDM-VTON /content/IDM-VTON
# Out:
# ^C

# %%
# التاكد اني المودل موجود
# !cd /content/IDM-VTON

# %%
# %cd IDM-VTON

# %%
# تثبيت بيئه المودل
# !conda env create -f /content/IDM-VTON/environment.yaml
# Out:
# Channels:
#  - pytorch
#  - nvidia
#  - defaults
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# pytorch-2.0.1        | 1.41 GB   | :   0% 0/1 [00:00<?, ?it/s]
# libcublas-11.11.3.6  | 364.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# libcusparse-11.7.5.8 | 176.3 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libnpp-11.8.0.86     | 147.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libcufft-10.9.0.58   | 142.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# mkl-2021.4.0         | 142.6 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libcusolver-11.4.1.4 | 96.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# torchtriton-2.0.0    | 62.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# بتاكد اني idm environment موجوده
# !conda env list

# %%
# !rm /content/high-resolution-viton-zalando-dataset.zip

# %%
# تحميل الداتا

# !kaggle datasets download -d marquis03/high-resolution-viton-zalando-dataset -p /content/IDM-VTON/data/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/marquis03/high-resolution-viton-zalando-dataset
# License(s): CC-BY-NC-SA-4.0
# User cancelled operation

# %%
# فك ضغط الداتا
# !unzip /content/drive/MyDrive/IDM-VTON/data/high-resolution-viton-zalando-dataset.zip -d /content/drive/MyDrive/IDM-VTON/data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08392_00_keypoints.json
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08393_00_keypoints.json
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08394_00_keypoints.json
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08396_00_keypoints.json
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08397_00_keypoints.json
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08398_00_keypoints.json
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08399_00_keypoints.json
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08400_00_keypoints.json
#   inflating: /content/drive/MyDrive/IDM-VTON/data/train/openpose_json/08403_00_keypoints.json
# ...

# %%
# !ls -lh ~/.cache/huggingface/hub
# Out:
# total 12K
# drwxr-xr-x 6 root root 4.0K May 25 02:07 models--yisol--IDM-VTON
# -rw-r--r-- 1 root root    1 May 25 02:01 version_diffusers_cache.txt
# -rw-r--r-- 1 root root    1 May 25 02:01 version.txt

# %%
# !ls -lh ~/.cache/huggingface/hub/models--yisol--IDM-VTON
# Out:
# total 12K
# drwxr-xr-x 2 root root 4.0K May 25 02:07 blobs
# drwxr-xr-x 2 root root 4.0K May 25 02:02 refs
# drwxr-xr-x 3 root root 4.0K May 25 02:02 snapshots

# %% [markdown]
# If you didnot work with enviroment

# %%
# !pip uninstall -y  PyTorch 2.5.1
# !pip uninstall -y Transformers  4.47.0
# !pip uninstall -y Diffusers 0.31.0
# !pip uninstall -y Huggingface Hub  0.29.0

# # Uninstall the specific versions
# !pip uninstall -y torch==2.5.1+cu121
# !pip uninstall -y transformers==4.47.0
# !pip uninstall -y diffusers==0.31.0
# !pip uninstall -y huggingface_hub==0.29.0

# # To be thorough, uninstall all related packages that might have dependencies
# !pip uninstall -y torch torchvision torchaudio
# !pip uninstall -y transformers
# !pip uninstall -y diffusers
# !pip uninstall -y huggingface_hub
# !pip uninstall -y accelerate
# !pip uninstall -y xformers

# # Uninstall additional torch-related packages
# !pip uninstall -y pytorch-ignite
# !pip uninstall -y pytorch-lightning
# !pip uninstall -y torchinfo
# !pip uninstall -y torchmetrics
# !pip uninstall -y torchsummary
# !pip uninstall -y torchtune
# !pip uninstall -y pytorch-ignite                     0.5.1
# !pip uninstall -y  pytorch-lightning                  2.5.0.post0
# !pip uninstall -y  torch                              2.5.1
# !pip uninstall -y  torchaudio                         2.5.1
# !pip uninstall -y  torchinfo                          1.8.0
# !pip uninstall -y  torchmetrics                       1.6.1
# !pip uninstall -y  torchsummary                       1.5.1
# !pip uninstall -y  torchtune                          0.5.0
# !pip uninstall -y  torchvision                        0.20.1
# !pip uninstall -y sentence-transformers              3.3.1
# !pip uninstall -y  torch                              2.5.1
# !pip uninstall -y  torchaudio                         2.5.1
# !pip uninstall -y  torchvision                        0.20.1

# # Uninstall additional transformers-related packages
# !pip uninstall -y sentence-transformers


# !pip uninstall -y  torch
# !pip uninstall -y  torchaudio
# !pip uninstall -y  torchvision

# %%
# import torch
# import transformers
# import diffusers
# import huggingface_hub

# print(f"PyTorch version: {torch._version_}")
# print(f"Transformers version: {transformers._version_}")
# print(f"Diffusers version: {diffusers._version_}")
# print(f"Huggingface Hub version: {huggingface_hub._version_}")

# %%
# # Clean up first - uninstall everything related
# !pip uninstall -y diffusers huggingface_hub transformers accelerate xformers torch torchvision torchaudio ninja tb-nightly triton

# # First install PyTorch 2.0.1 with CUDA 11.7 (both torch and torchvision from same CUDA version)
# !pip install --no-cache-dir torch==2.0.1+cu117 torchvision==0.15.2+cu117 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu117

# # Install ninja (required by easyocr)
# !pip install ninja

# # Install a compatible xformers version for torch 2.0.1
# !pip install xformers==0.0.20

# # HuggingFace ecosystem
# !pip install huggingface_hub==0.19.4
# !pip install transformers==4.36.2
# !pip install accelerate==0.25.0
# !pip install diffusers==0.25.0
# !pip install safetensors==0.4.1
# !pip install peft==0.7.1

# # Computer vision
# !pip install Pillow==10.0.0
# !pip install opencv-python==4.8.1.78
# !pip install scikit-image==0.21.0

# # Optimization
# !pip install bitsandbytes==0.39.0

# # Other requirements
# !pip install tqdm==4.66.1
# !pip install omegaconf==2.3.0
# !pip install einops==0.7.0
# !pip install gradio==4.24.0
# !pip install basicsr==1.4.2

# %% [markdown]
# important dependencies

# %%
# !source activate idm && pip install huggingface_hub==0.19.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 6.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.33.0
#     Uninstalling huggingface-hub-0.33.0:
#       Successfully uninstalled huggingface-hub-0.33.0
# ...

# %%
# !source activate idm && pip install gradio==3.50.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 105.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 27.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 0.14.0
#     Uninstalling gradio_client-0.14.0:
#       Successfully uninstalled gradio_client-0.14.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 4.24.0
#     Uninstalling gradio-4.24.0:
#       Successfully uninstalled gradio-4.24.0
# ...

# %%
# !conda init
# !conda deactivate
# !conda init
# !conda activate idm
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.11/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
#
# CondaError: Run 'conda init' before 'conda deactivate'
#
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# ...

# %%
# !source activate idm && pip install gradio flask requests pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# !source activate idm && pip install pyngrok flask-cors cloudinary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.3/147.3 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# Navigate to directory
# %cd /content/IDM-VTON

# Set environment variables for device consistency
# !export CUDA_LAUNCH_BLOCKING=1
# !export TORCH_USE_CUDA_DSA=1


# Run with explicit device configuration
# !source activate idm && unset MPLBACKEND && CUDA_VISIBLE_DEVICES=0 accelerate launch --gpu_ids=0 /content/IDM-VTON/gradio_demo/app.py
# Out:
# /content/IDM-VTON
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# Public URL: NgrokTunnel: "https://e420-34-56-147-65.ngrok-free.app" -> "http://localhost:5000"
# Initializing models...
# config.json: 100% 1.94k/1.94k [00:00<00:00, 11.4MB/s]
# diffusion_pytorch_model.bin:  53% 6.29G/12.0G [00:28<00:32, 174MB/s]t=2025-06-15T11:45:00+0000 lvl=warn msg="failed to open private leg" id=36cefbe40911 privaddr=localhost:5000 err="dial tcp 127.0.0.1:5000: connect: connection refused"
# ...

# %%
# # بشوف اي الفيلات اللي موجوده جواه ملف الداتا
# !ls /content/drive/MyDrive/IDM-VTON/data/
# Out:
# test  test_pairs.txt  train  train_pairs.txt

# %%
# import shutil

# # تحديد المسارات الخاصة بالملفات
# source_train_file = '/content/drive/MyDrive/IDM-VTON/vitonhd_train_tagged.json'  # المسار إلى الملف vitonhd_train_tagged.json
# destination_train_folder = '/content/drive/MyDrive/IDM-VTON/data/train/'

# # نقل الملف إلى المجلد المناسب
# shutil.move(source_train_file, destination_train_folder)

# # تكرار نفس العملية للملف vitonhd_test_tagged.json
# source_test_file = '/content/drive/MyDrive/IDM-VTON/vitonhd_test_tagged.json'  # المسار إلى الملف vitonhd_test_tagged.json
# destination_test_folder = '/content/drive/MyDrive/IDM-VTON/data/test/'

# shutil.move(source_test_file, destination_test_folder)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-8-f1f6bdbacc2f> in <cell line: 0>()
#       6
#       7 # نقل الملف إلى المجلد المناسب
# ----> 8 shutil.move(source_train_file, destination_train_folder)
#       9
#      10 # تكرار نفس العملية للملف vitonhd_test_tagged.json
#
# /usr/lib/python3.11/shutil.py in move(src, dst, copy_function)
#     849
#     850         if os.path.exists(real_dst):
# --> 851             raise Error("Destination path '%s' already exists" % real_dst)
#     852     try:
#     853         os.rename(src, real_dst)
#
# Error: Destination path '/content/drive/MyDrive/IDM-VTON/data/train/vitonhd_train_tagged.json' already exists

# %%
# محتاجه المكتبه دي
# !pip install opencv-python-headless
# !pip install einops
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 92.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 179.2 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.6.0+cu124
# True

# %%
# ✅ 1. تفريغ الكاش لتقليل استهلاك VRAM
import torch
torch.cuda.empty_cache()

# ✅ 2. إعدادات PyTorch لتقليل تجزئة الذاكرة
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:128"

# ✅ 3. تفعيل CUDA debugging للمساعدة في تتبع الأخطاء
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# ✅ 4. تسجيل أي أخطاء أثناء التدريب (ضيفيه حول كود التدريب نفسه)
try:
    # حطي هنا كود التدريب بتاعك
    pass
except Exception as e:
    print("❌ Error occurred during training:", e)

# %%
# # ب active ال environment وبدرب المودل ع الصور
# !source activate idm && python /content/IDM-VTON/preprocess/humanparsing/run_parsing.py

# %%
# ب active ال environment وبدرب المودل ع الصور
# !source activate idm && python /content/IDM-VTON/preprocess/openpose/run_openpose.py

# %%
# !source activate idm && accelerate launch /content/drive/MyDrive/IDM-VTON/train_xl.py \
#     --gradient_checkpointing --use_8bit_adam \
#     --output_dir=/content/drive/MyDrive/IDM-VTON/result\
#     --train_batch_size=1 \
#     --width=384 --height=512\
#     --data_dir=/content/drive/MyDrive/IDM-VTON/data\
#     --image_encoder_path=/content/drive/MyDrive/IDM-VTON/ckpt/image_encoder
# Out:
# The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# Traceback (most recent call last):
#   File "/usr/local/envs/idm/bin/accelerate", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/envs/idm/lib/python3.10/site-packages/accelerate/commands/accelerate_cli.py", line 47, in main
#     args.func(args)
#   File "/usr/local/envs/idm/lib/python3.10/site-packages/accelerate/commands/launch.py", line 1017, in launch_command
#     simple_launcher(args)
#   File "/usr/local/envs/idm/lib/python3.10/site-packages/accelerate/commands/launch.py", line 637, in simple_launcher
#     raise subprocess.CalledProcessError(returncode=process.returncode, cmd=cmd)
# ...

# %%
# !source activate idm && accelerate launch /content/IDM-VTON/inference.py \
    --width 768 --height 1024 --num_inference_steps 30 \
    --output_dir "results" \
    --unpaired \
    --data_dir "/content/IDM-VTON/data" \
    --seed 42 \
    --test_batch_size 1 \
    --guidance_scale 2.0
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# {'dynamic_thresholding_ratio', 'clip_sample_range', 'thresholding', 'variance_type'} was not found in config. Values will be initialized to default values.
# The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# {'reverse_transformer_layers_per_block', 'dropout'} was not found in config. Values will be initialized to default values.
# ...
